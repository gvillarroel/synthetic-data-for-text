# %%
import os
real_path = "../docs/tesis/imagenes/kingcounty/top2"
fake_path = "imagenes/kingcounty/top2"
files = [ f.replace(".svg", "") for f in os.listdir(real_path) ]

for f in files:
    m = f.replace('_', ' ')
    print(f"""\\begin{{figure}}[H]
        \\centering
        \\includesvg[scale=.5,inkscapelatex=false]{{{fake_path}/{f}.svg}}
        \\caption{{Smote y TDDPM en King County: {m}}}
        \\label{{pair-{f}}}
    \end{{figure}}""")
# Out:
# \begin{figure}[H]
#         \centering
#         \includesvg[scale=.5,inkscapelatex=false]{imagenes/kingcounty/top2/field_bathrooms.svg}
#         \caption{Smote y TDDPM en King County: field bathrooms}
#         \label{pair-field_bathrooms}
#     \end{figure}
# \begin{figure}[H]
#         \centering
#         \includesvg[scale=.5,inkscapelatex=false]{imagenes/kingcounty/top2/field_sqft_lot.svg}
#         \caption{Smote y TDDPM en King County: field sqft lot}
#         \label{pair-field_sqft_lot}
#     \end{figure}
# \begin{figure}[H]
#         \centering
#         \includesvg[scale=.5,inkscapelatex=false]{imagenes/kingcounty/top2/privacy.svg}
#         \caption{Smote y TDDPM en King County: privacy}
#         \label{pair-privacy}
#     \end{figure}
# \begin{figure}[H]
#         \centering
#         \includesvg[scale=.5,inkscapelatex=false]{imagenes/kingcounty/top2/field_bedrooms.svg}
#         \caption{Smote y TDDPM en King County: field bedrooms}
# ...
