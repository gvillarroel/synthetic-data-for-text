# %% [markdown]
# # Economicos

# %%
# %%capture
import sys
# !ln -s ../syntheticml .
# !{sys.executable} -m pip install -U -r ../requirements.txt
# !{sys.executable} -m pip install -U kaleido

# %%
import pandas as pd
import numpy as np
from syntheticml.data.synthetic import Synthetic, MODELS

df = pd.read_parquet('../datasets/economicos/raw/full_dedup_economicos_step0.parquet');
df.sample(3)
# Out:
#                                                       url  \
# 202672  https://www.economicos.cl/propiedades/departam...
# 411927  https://www.economicos.cl/propiedades/departam...
# 138294  https://www.economicos.cl/propiedades/casa-cen...
#
#                                               description         price  \
# 202672  Descripción detallada\nExcelente oportunidad!...  $ 55.000.000
# 411927  385.000 Arriendo cómodo departamento a 4 cuad...     $ 385.000
# 138294  Vendo casa aislada de 1 piso, 84 mts2 construi...       4000 UF
#
#        property_type transaction_type                      state      county  \
# 202672  Departamento            Venta                     Biobío  Concepción
# 411927  Departamento         Arriendo  Metropolitana de Santiago    Santiago
# 138294          Casa            Venta                   Coquimbo   La Serena
#
#           publication_date  rooms  bathrooms  m_built  m_size       source  \
# 202672 2019-03-20 21:14:28    3.0        2.0     68.0     NaN         None
# 411927 2018-04-10 00:00:03    NaN        2.0      NaN     NaN  El Mercurio
# 138294 2019-12-30 11:11:21    3.0        2.0     84.0   232.0         None
#
#                                                title  \
# 202672            Departamento Central en Concepción
# 411927  Departamento en Arriendo en Santiago 2 baños
# 138294                                          None
#
#                                      address owner       _price
# 202672  Concepción centro Concepción, Biobío  None  1995.228881
# 411927   Santiago, Metropolitana de Santiago  None    14.275814
# 138294                                  None  None  4000.000000

# %%
# %%capture
category_columns=("property_type", "transaction_type", "state", "county", "rooms", "bathrooms", "source", )
df_converted = df.fillna(dict(
        property_type = "None",
        transaction_type = "None",
        state = "None",
        county = "None",
        rooms = -1,
        bathrooms = -1,
        m_built = -1,
        m_size = -1,
        source = "None"
)).fillna(-1).astype({k: 'str' for k in ("description", "price", "title", "address", "owner",)})
print(df_converted.shape)
basedate = pd.Timestamp('2017-12-01')
dtime = df_converted.pop("publication_date")
df_converted["publication_date"] = dtime.apply(lambda x: (x - basedate).days)
syn = Synthetic(df_converted, 
        id="url", 
        category_columns=category_columns,
        text_columns=("description", "price", "title", "address", "owner", ),
        exclude_columns=tuple(),
        synthetic_folder = "../datasets/economicos/synth-b",
        models=['copulagan', 'tvae', 'gaussiancopula', 'smote-enc', 
                'tddpm_mlp'
                ],
        n_sample = df_converted.shape[0],
        target_column="_price",
        max_cpu_pool=1,
        use_noise=False
)

# %%
# %%capture
syn.process()
syn.process_scores()

# %% [markdown]
# ## Metricas
# ### Continuas

# %%
metrics = syn.current_metrics()
metrics[~metrics.is_categorical].dropna(axis=1, how='all')
# Out:
#                name                                   top5  \
# 2  publication_date         [1545, 1693, 1392, 1492, 1408]
# 3            m_size      [-1.0, 5000.0, 200.0, 60.0, 50.0]
# 5            _price  [0.0, 3500.0, 5500.0, 6500.0, 4500.0]
# 9           m_built        [-1.0, 60.0, 50.0, 70.0, 100.0]
#
#                              top5_freq  \
# 2    [19744, 11666, 10260, 3838, 2445]
# 3    [245062, 19573, 6932, 6312, 5748]
# 5          [17989, 865, 767, 763, 740]
# 9  [188514, 13831, 11796, 11648, 9716]
#
#                                            top5_prob  is_categorical  \
# 2  [0.036169784014508946, 0.021371388792203273, 0...           False
# 3  [0.44893839192481727, 0.0358565226152747, 0.01...           False
# 5  [0.03295473281184165, 0.001584626376243428, 0....           False
# 9  [0.3453459614926631, 0.025337534577829886, 0.0...           False
#
#        nobs  missing          mean       std_err      upper_ci  ...  \
# 2  545870.0      0.0  7.027108e+02  6.245781e-01  7.039349e+02  ...
# 3  545870.0      0.0  2.035506e+16  2.035487e+16  6.024986e+16  ...
# 5  545870.0      0.0  7.098298e+09  7.021735e+09  2.086065e+10  ...
# 9  545870.0      0.0  2.271416e+09  2.043921e+09  6.277428e+09  ...
#
#    mode_freq     median  0.1%  1.0%       5.0%      25.0%   75.0%    95.0%  \
# 2   0.036170  609.00000  42.0  56.0  100.00000  322.00000  1037.0   1545.0
# 3   0.448938   36.00000  -1.0  -1.0   -1.00000   -1.00000   180.0   5000.0
# 5   0.032955  174.02451   0.0   0.0    1.26969   12.28306  3550.0  14400.0
# 9   0.345346   50.00000  -1.0  -1.0   -1.00000   -1.00000    98.0    400.0
#
#       99.0%         99.9%
# 2   1693.00  1.693000e+03
# 3  50000.00  4.920000e+06
# 5  47000.00  1.906676e+06
# 9   8350.51  5.500000e+05
#
# [4 rows x 35 columns]

# %% [markdown]
# ### Categoricas

# %%
metrics[metrics.is_categorical].dropna(axis=1, how='all')
# Out:
#                 name                                               top5  \
# 0      property_type  [Departamento, Casa, Sitio o Terreno, Parcela ...
# 1             source  [None, El Mercurio, [El Mercurio de Valparaiso...
# 4   transaction_type    [Venta, Arriendo, Busco arriendo, Compro, None]
# 6              rooms                         [-1.0, 3.0, 2.0, 1.0, 4.0]
# 7              state  [Metropolitana de Santiago, Valparaíso, Biobío...
# 8          bathrooms                         [-1.0, 2.0, 1.0, 3.0, 4.0]
# 10            county  [Santiago, Viña del Mar, Las Condes, Providenc...
#
#                                  top5_freq  \
# 0    [211405, 142054, 31393, 30020, 27415]
# 1      [371221, 135613, 13594, 6979, 4132]
# 4         [282495, 258300, 3031, 1901, 86]
# 6    [196417, 125902, 97220, 54183, 44539]
# 7    [272808, 108197, 29379, 21581, 16533]
# 8   [206916, 136581, 134963, 43884, 14719]
# 10     [65125, 33263, 32327, 27981, 24863]
#
#                                             top5_prob  is_categorical  \
# 0   [0.38728085441588656, 0.26023412167732246, 0.0...            True
# 1   [0.6800538589774122, 0.24843460897283237, 0.02...            True
# 4   [0.5175133273490025, 0.473189587264367, 0.0055...            True
# 6   [0.35982376756370565, 0.23064465898473996, 0.1...            True
# 7   [0.49976734387308336, 0.1982101965669482, 0.05...            True
# 8   [0.3790572847014857, 0.2502079249638192, 0.247...            True
# 10  [0.11930496272006155, 0.06093575393408687, 0.0...            True
#
#         nobs   missing
# 0   545870.0  545870.0
# 1   545870.0  545870.0
# 4   545870.0  545870.0
# 6   545870.0  545870.0
# 7   545870.0  545870.0
# 8   545870.0  545870.0
# 10  545870.0  545870.0

# %%
syn.scores.index.unique()
# Out:
# Index(['copulagan_682338', 'gaussiancopula_682338', 'smote-enc_682338',
#        'tddpm_mlp_682338', 'tvae_682338'],
#       dtype='object', name='name')

# %% [markdown]
# ## Scores

# %%
#best_model = "smote-enc_noise_682338"
best_model = "tddpm_mlp_27574"
second_best_model= "smote-enc_27574"
avg = syn.scores[syn.scores["type"] == "avg"]
avg.sort_values("score", ascending=False).loc[:,["score", "DCR ST 5th", "DCR SH 5th", "DCR TH 5th"]]
# Out:
#                           score    DCR ST 5th    DCR SH 5th    DCR TH 5th
# name
# tddpm_mlp_682338       0.966218  8.050782e-15  8.062921e-15  9.000000e-17
# smote-enc_682338       0.947804  7.093774e-15  8.920271e-15  9.000000e-17
# tvae_682338            0.766746  1.274006e-14  1.233074e-14  9.000000e-17
# gaussiancopula_682338  0.714859  4.833396e-04  4.836043e-04  9.000000e-17
# copulagan_682338       0.670387  2.724884e-10  2.705633e-10  9.000000e-17

# %%
def formater(x):
    return '{:.2e}'.format(x)
sci_format = { k: formater for k in ["DCR ST 5th", "DCR SH 5th", "DCR TH 5th"]}

print(avg.sort_values("score", ascending=False).loc[:,["score", "DCR ST 5th", "DCR SH 5th", "DCR TH 5th"]].style.format(sci_format).to_latex().replace("_", "\_"))
# Out:
# \begin{tabular}{lrrrr}
#  & score & DCR ST 5th & DCR SH 5th & DCR TH 5th \\
# name &  &  &  &  \\
# tddpm\_mlp\_682338 & 0.966218 & 8.05e-15 & 8.06e-15 & 9.00e-17 \\
# smote-enc\_682338 & 0.947804 & 7.09e-15 & 8.92e-15 & 9.00e-17 \\
# tvae\_682338 & 0.766746 & 1.27e-14 & 1.23e-14 & 9.00e-17 \\
# gaussiancopula\_682338 & 0.714859 & 4.83e-04 & 4.84e-04 & 9.00e-17 \\
# copulagan\_682338 & 0.670387 & 2.72e-10 & 2.71e-10 & 9.00e-17 \\
# \end{tabular}

# %%
import os
folder_path = f"../docs/tesis/imagenes/economicos/top2-b"
if not os.path.exists(folder_path):
    os.mkdir(folder_path)
for fig in syn.get_multiple_charts([best_model,second_best_model], {'date', 'id', 'zipcode', 'lat', 'long', 'yr_renovated'}):
    if fig:
        file_name = f'{fig.layout.title.text.replace(":","").replace(" ","_").lower()}.svg'
        fig.write_image(f"{folder_path}/{file_name}")
        display(fig.show("png"))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.pyenv/versions/3.9.15/envs/syn/lib/python3.9/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/.pyenv/versions/3.9.15/envs/syn/lib/python3.9/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.pyenv/versions/3.9.15/envs/syn/lib/python3.9/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'tddpm_mlp_27574'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /home/gvillarroel/dev/synthetic-data-for-text/notebooks/economicos-b.ipynb Cell 14 in 5
#       <a href='vscode-notebook-cell:/home/gvillarroel/dev/synthetic-data-for-text/notebooks/economicos-b.ipynb#X16sZmlsZQ%3D%3D?line=2'>3</a> if not os.path.exists(folder_path):
#       <a href='vscode-notebook-cell:/home/gvillarroel/dev/synthetic-data-for-text/notebooks/economicos-b.ipynb#X16sZmlsZQ%3D%3D?line=3'>4</a>     os.mkdir(folder_path)
# ----> <a href='vscode-notebook-cell:/home/gvillarroel/dev/synthetic-data-for-text/notebooks/economicos-b.ipynb#X16sZmlsZQ%3D%3D?line=4'>5</a> for fig in syn.get_multiple_charts([best_model,second_best_model], {'date', 'id', 'zipcode', 'lat', 'long', 'yr_renovated'}):
#       <a href='vscode-notebook-cell:/home/gvillarroel/dev/synthetic-data-for-text/notebooks/economicos-b.ipynb#X16sZmlsZQ%3D%3D?line=5'>6</a>     if fig:
#       <a href='vscode-notebook-cell:/home/gvillarroel/dev/synthetic-data-for-text/notebooks/economicos-b.ipynb#X16sZmlsZQ%3D%3D?line=6'>7</a>         file_name = f'{fig.layout.title.text.replace(":","").replace(" ","_").lower()}.svg'
#
# File ~/dev/synthetic-data-for-text/notebooks/syntheticml/data/synthetic.py:317, in Synthetic.get_multiple_charts(self, models, exclude_columns, privacy_cut)
#     315 def get_multiple_charts(self, models: list[str], exclude_columns: set[str] = set(), privacy_cut=0.05) -> list[go.Figure]:
# --> 317     serie_real = self.privacy_metrics.loc[models[0], :]["DCR TH"]
#     318     serie_real = serie_real[serie_real <=
#     319                             np.quantile(serie_real, privacy_cut)]
#     321     serie_fakes = []
#
# File ~/.pyenv/versions/3.9.15/envs/syn/lib/python3.9/site-packages/pandas/core/indexing.py:1067, in _LocationIndexer.__getitem__(self, key)
#    1065     if self._is_scalar_access(key):
#    1066         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067     return self._getitem_tuple(key)
#    1068 else:
#    1069     # we by definition only have the 0th axis
#    1070     axis = self.axis or 0
#
# File ~/.pyenv/versions/3.9.15/envs/syn/lib/python3.9/site-packages/pandas/core/indexing.py:1247, in _LocIndexer._getitem_tuple(self, tup)
#    1245 with suppress(IndexingError):
#    1246     tup = self._expand_ellipsis(tup)
# -> 1247     return self._getitem_lowerdim(tup)
#    1249 # no multi-index, so validate all of the indexers
#    1250 tup = self._validate_tuple_indexer(tup)
#
# File ~/.pyenv/versions/3.9.15/envs/syn/lib/python3.9/site-packages/pandas/core/indexing.py:967, in _LocationIndexer._getitem_lowerdim(self, tup)
#     963 for i, key in enumerate(tup):
#     964     if is_label_like(key):
#     965         # We don't need to check for tuples here because those are
#     966         #  caught by the _is_nested_tuple_indexer check above.
# --> 967         section = self._getitem_axis(key, axis=i)
#     969         # We should never have a scalar section here, because
#     970         #  _getitem_lowerdim is only called after a check for
#     971         #  is_scalar_access, which that would be.
#     972         if section.ndim == self.ndim:
#     973             # we're in the middle of slicing through a MultiIndex
#     974             # revise the key wrt to `section` by inserting an _NS
#
# File ~/.pyenv/versions/3.9.15/envs/syn/lib/python3.9/site-packages/pandas/core/indexing.py:1312, in _LocIndexer._getitem_axis(self, key, axis)
#    1310 # fall thru to straight lookup
#    1311 self._validate_key(key, axis)
# -> 1312 return self._get_label(key, axis=axis)
#
# File ~/.pyenv/versions/3.9.15/envs/syn/lib/python3.9/site-packages/pandas/core/indexing.py:1260, in _LocIndexer._get_label(self, label, axis)
#    1258 def _get_label(self, label, axis: int):
#    1259     # GH#5567 this will fail if the label is not present in the axis.
# -> 1260     return self.obj.xs(label, axis=axis)
#
# File ~/.pyenv/versions/3.9.15/envs/syn/lib/python3.9/site-packages/pandas/core/generic.py:4056, in NDFrame.xs(self, key, axis, level, drop_level)
#    4054             new_index = index[loc]
#    4055 else:
# -> 4056     loc = index.get_loc(key)
#    4058     if isinstance(loc, np.ndarray):
#    4059         if loc.dtype == np.bool_:
#
# File ~/.pyenv/versions/3.9.15/envs/syn/lib/python3.9/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'tddpm_mlp_27574'

# %%
import os
folder_path = f"../docs/tesis/imagenes/economicos/top2+1-b"
if not os.path.exists(folder_path):
    os.mkdir(folder_path)
for fig in syn.get_multiple_charts([best_model,second_best_model,"copulagan_27574"], {'date', 'id', 'zipcode', 'lat', 'long', 'yr_renovated'}):
    if fig:
        file_name = f'{fig.layout.title.text.replace(":","").replace(" ","_").lower()}.svg'
        fig.write_image(f"{folder_path}/{file_name}")
        display(fig.show("png"))

# %%
syn.charts.pair_corr(df.loc[:, syn.fake_data[best_model].columns].dropna(), syn.fake_data[best_model].astype({k:np.float64 for k in ('bathrooms','rooms','m_built','m_size')}), {'id', 'waterfront', 'yr_renovated'}, "_price").update_layout(dict(width=1000)).show("png")

# %%
syn.charts.pair_corr(df.loc[:, syn.fake_data[second_best].columns].dropna(), syn.fake_data[second_best].astype({k:np.float64 for k in ('bathrooms','rooms','m_built','m_size')}), {'id', 'waterfront', 'yr_renovated'}, "_price").update_layout(dict(width=1000)).show("png")
